# %% [markdown]
# <a href="https://colab.research.google.com/github/RuthBiney/new_sum/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Preparation and Preprocessing.

# %%
import pandas as pd

# Load the dataset
file_path = '/content/Medical-Equipment-Suppliers.csv'
data = pd.read_csv(file_path, on_bad_lines='skip') # Use on_bad_lines to handle bad lines

# Display the first few rows of the dataset
data.head()
# Out:
# <ipython-input-5-b778a1ceffd0>:5: DtypeWarning: Columns (1,10,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, on_bad_lines='skip') # Use on_bad_lines to handle bad lines
#    provider_id acceptsassignement participationbegindate     businessname  \
# 0   20340071.0               True             2023-01-01  HOOK-SUPERX LLC
# 1   20339915.0               True             2023-01-01  HOOK-SUPERX LLC
# 2   20339909.0               True             2023-01-01  HOOK-SUPERX LLC
# 3   20339903.0               True             2023-01-01  HOOK-SUPERX LLC
# 4   20340233.0               True             2023-01-01  HOOK-SUPERX LLC
#
#           practicename  practiceaddress1 practiceaddress2 practicecity  \
# 0   CVS PHARMACY #6756   201 E TIPTON ST              NaN      SEYMOUR
# 1  CVS PHARMACY #06513     486 N CASS ST              NaN       WABASH
# 2  CVS PHARMACY #06550    1700 E MAIN ST              NaN   PLAINFIELD
# ...

# %% [markdown]
# Data Preprocessing

# %%
import pandas as pd

# Load the dataset
file_path = '/content/Medical-Equipment-Suppliers.csv'
data = pd.read_csv(file_path, on_bad_lines='skip') # Use on_bad_lines to handle bad lines

# Display the first few rows of the dataset
data.head()

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# Identify categorical and numerical columns
# 'latitude', 'longitude' appear to have non-numeric values. Moving them to categorical
# Out:
# <ipython-input-9-77cbbf863a26>:5: DtypeWarning: Columns (1,10,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, on_bad_lines='skip') # Use on_bad_lines to handle bad lines

# %% [markdown]
# Next Steps:
#
# 1.Save the trained model as a .pkl file.
#
# 2.Create a UI to depict the whole pipeline process.
#
# 3.Deploy the model using Flask and a cloud platform.
#
# 4.Set up retraining triggers and demonstrate the evaluation process in production.
#
# 5.Optionally, simulate a flood of requests to test the model's performance under load.
#
# Save the Trained Model
#
# We'll save the trained model as a .pkl file.

# %%
import joblib

# Save the model to a file
model_file_path = '/content/Medical-Equipment-Suppliers.csv'
joblib.dump(model, model_file_path)
# Out:
# ['/content/Medical-Equipment-Suppliers.csv']
